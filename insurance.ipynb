# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharsh19-04/AIML-016/blob/main/insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 6    55
# 0    22
# 12   27
# 11   28
# 4    46
# 26   23

# %%
plt.scatter(df.age,df.bought_insurance,marker=&#39;+&#39;,color=&#39;red&#39;)
# Out:
#   File "/tmp/ipython-input-139166066.py", line 1
#     plt.scatter(df.age,df.bought_insurance,marker=&#39;+&#39;,color=&#39;red&#39;)
#                                                   ^
# SyntaxError: invalid syntax

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 6    55
# 0    22
# 12   27
# 11   28
# 4    46
# 26   23

# %%
y_predicted = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
X_test
# Out:
#     age
# 6    55
# 0    22
# 12   27
# 11   28
# 4    46
# 26   23

# %%
model.coef_
model.intercept_
# Out:
# array([-5.2587925])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
